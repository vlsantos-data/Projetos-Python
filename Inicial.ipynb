# %% [markdown]
# https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga
# # Automação de Sistemas e Processos com Python
#
# ### Desafio:
#
# Todos os dias, o nosso sistema atualiza as vendas do dia anterior.
# O seu trabalho diário, como analista, é enviar um e-mail para a diretoria, assim que começar a trabalhar, com o faturamento e a quantidade de produtos vendidos no dia anterior
#
# E-mail da diretoria: seugmail+diretoria@gmail.com<br>
# Local onde o sistema disponibiliza as vendas do dia anterior: https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga
#
# Para resolver isso, vamos usar o pyautogui, uma biblioteca de automação de comandos do mouse e do teclado
#
#
# Referência do pyautogui: https://pyautogui.readthedocs.io/en/latest/quickstart.html

# %% [markdown]
# https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga
# # vamos precisar instalar
# # pyautogui -> automações
# # pandas -> dados
# # openpyxl -> trabalhar com bases de dados em Excel (.xlsx)
# # para instalar: abrir o terminal e rodar: pip install pandas pyautogui openpyxl
#
# # pyautogui.click -> clicar com o mouse
# # pyautogui.write -> escrever um texto
# # pyautogui.press -> aperta 1 tecla
# # pyautogui.hotkey -> combinação de teclas

# %%
import pyautogui
import time
import pandas
# Passo a passo do desafio
pyautogui.PAUSE = 1
# Passo 1: Entrar no sistema da empresa (link do drive)
# abrir o Chrome1
pyautogui.press('win')
pyautogui.write('Chrome')
pyautogui.press('enter')
# digitei o link do sistema
link = 'https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga'
pyautogui.write(link)
pyautogui.press('Enter')
time.sleep(3)

# %%
# Passo 2: Navegar no sistema para encontrar a base de dados
#Clicando Na Pasta
pyautogui.click(x=390, y=426, clicks = 2)
time.sleep(2)
# Clickar em Baixar
pyautogui.click(x=1372, y=430, clicks = 1)
time.sleep(2)
# P	asso 3: Exportar a base de dados (baixar o arquivo)

# %% [markdown]
# ### Vamos agora ler o arquivo baixado para pegar os indicadores
#
# - Faturamento
# - Quantidade de Produtos

# %%
# Passo 4: Calcular os indicadores (faturamento e quantidade de produtos vendidos)
# abrir a base de dados
caminho  = r'C:\Users\vluca\Downloads\Vendas - Dez.xlsx'
tabela = pandas.read_excel(caminho)
# ver as informações da base de dados
display(tabela)
import pandas
# somar o faturamento de todos os produtos = somar a coluna de Valor Final
#criar uma tabela com as informações do faturamento	
Faturamento = tabela['Valor Final'].sum()
# somar a quantidade de produtos = somar a coluna de quantidade
Quantidade = tabela['Quantidade'].sum()
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# 0              5             114          570
# 1              1             269          269
# 2              2             363          726
# 3              1             250          250
# 4              3              92          276
# ...          ...             ...          ...
# 7084           2             102          204
# 7085           4             270         1080
# 7086           1              87           87
# 7087           1             108          108
# 7088           2             133          266
#
# [7089 rows x 7 columns]

# %% [markdown]
# ### Vamos agora enviar um e-mail pelo gmail

# %%
import pyperclip
import pyautogui
import time
pyautogui.hotkey('ctrl', 't')
time.sleep(3)
link_gmail = 'https://mail.google.com/mail'
pyautogui.write(link_gmail)
pyautogui.press('Enter')
pyautogui.click(x=32, y=226)
time.sleep(2)
email = 'gameplaysvictor97@gmail.com'
pyautogui.write(email)
pyautogui.press('tab')
pyautogui.press('tab')
time.sleep(1)
pyperclip.copy("Relatório de vendas")
pyautogui.hotkey("ctrl", "v")
pyautogui.press('tab')
texto = f"""
Prezados,

Segue o Relátorio de vendas de hoje

Faturamento: R${Faturamento:,.2f}	
Quantidade: {Quantidade:,}

Qualquer dúvida estou à disposição
abs,

Victor Lucas
"""
pyperclip.copy(texto)
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=1303, y=1054)

# %% [markdown]
# #### Use esse código para descobrir qual a posição de um item que queira clicar
#
# - Lembre-se: a posição na sua tela é diferente da posição na minha tela

# %%
print(pyautogui.position())
# Out:
# Point(x=1303, y=1054)
